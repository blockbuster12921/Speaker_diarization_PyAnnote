# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q https://github.com/pyannote/pyannote-audio/tarball/develop
# Out:
#      - 16.6 MB 8.0 MB/s 0:00:04
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 12.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 64.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 kB 4.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.9/113.9 kB 11.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.0/519.0 kB 36.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 12.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.9/47.9 kB 5.1 MB/s eta 0:00:00
# ...

# %%
from pyannote.audio import Pipeline

pipeline = Pipeline.from_pretrained('pyannote/speaker-diarization', use_auth_token='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')

diarization = pipeline('/content/drive/My Drive/deliver/Alrajhi_call.wav')
# Out:
# ...
# INFO:pytorch_lightning.utilities.migration.utils:Lightning automatically upgraded your loaded checkpoint from v1.5.4 to v2.0.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../root/.cache/torch/pyannote/models--pyannote--segmentation/snapshots/c4c8ceafcbb3a7a280c2d357aee9fbc9b0be7f9b/pytorch_model.bin`
# Model was trained with pyannote.audio 0.0.1, yours is 2.1.1. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.10.0+cu102, yours is 2.0.1+cu118. Bad things might happen unless you revert torch to 1.x.
# ...

# %%
for turn, _, speaker in diarization.itertracks(yield_label=True):
    print(f"start={turn.start:.1f}s stop={turn.end:.1f}s speaker_{speaker}")
# Out:
# start=1.5s stop=9.5s speaker_SPEAKER_00
# start=10.9s stop=12.8s speaker_SPEAKER_01
# start=15.3s stop=19.7s speaker_SPEAKER_00
# start=20.9s stop=21.3s speaker_SPEAKER_00
# start=21.2s stop=21.2s speaker_SPEAKER_01
# start=22.9s stop=30.1s speaker_SPEAKER_00
# start=32.1s stop=33.6s speaker_SPEAKER_01
# start=36.2s stop=40.6s speaker_SPEAKER_00
# start=41.8s stop=42.2s speaker_SPEAKER_01
# start=44.2s stop=45.2s speaker_SPEAKER_00
# start=47.2s stop=50.0s speaker_SPEAKER_01
# start=54.8s stop=58.3s speaker_SPEAKER_00
# start=61.3s stop=63.4s speaker_SPEAKER_01
# start=66.1s stop=70.9s speaker_SPEAKER_00
# start=72.1s stop=72.4s speaker_SPEAKER_00
# start=74.3s stop=77.0s speaker_SPEAKER_00
# start=78.6s stop=83.9s speaker_SPEAKER_01
# start=86.6s stop=87.5s speaker_SPEAKER_00
# start=92.5s stop=97.6s speaker_SPEAKER_00
# start=99.8s stop=100.2s speaker_SPEAKER_01
# start=102.1s stop=103.1s speaker_SPEAKER_00
# start=105.4s stop=108.0s speaker_SPEAKER_01
# ...
